# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
    base_url=os.getenv("ANTHROPIC_BASE_URI")
)
model = "claude-sonnet-4-6"

# %%
# Helper functions


def add_user_message(messages, message):
    if isinstance(message, list):
        user_message = {
            "role": "user",
            "content": message,
        }
    else:
        user_message = {
            "role": "user",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(user_message)


def add_assistant_message(messages, message):
    if isinstance(message, list):
        assistant_message = {
            "role": "assistant",
            "content": message,
        }
    elif hasattr(message, "content"):
        content_list = []
        for block in message.content:
            if block.type == "text":
                content_list.append({"type": "text", "text": block.text})
            elif block.type == "tool_use":
                content_list.append(
                    {
                        "type": "tool_use",
                        "id": block.id,
                        "name": block.name,
                        "input": block.input,
                    }
                )
        assistant_message = {
            "role": "assistant",
            "content": content_list,
        }
    else:
        # String messages need to be wrapped in a list with text block
        assistant_message = {
            "role": "assistant",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(assistant_message)


def chat_stream(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    tool_choice=None,
    betas=[],
):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tool_choice:
        params["tool_choice"] = tool_choice

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if betas:
        params["betas"] = betas

    return client.beta.messages.stream(**params)


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Tool definition
from anthropic.types import ToolParam

save_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Eight sentence review of the paper",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)
save_short_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Review of paper. One short sentence max",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)


def save_article(**kwargs):
    return "Article saved!"

# %%
# Tool Running
import json


def run_tool(tool_name, tool_input):
    if tool_name == "save_article":
        return save_article(**tool_input)


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Run conversation
def run_conversation(messages, tools=[], tool_choice=None, fine_grained=False):
    while True:
        with chat_stream(
            messages,
            tools=tools,
            betas=["fine-grained-tool-streaming-2025-05-14"] if fine_grained else [],
            tool_choice=tool_choice,
        ) as stream:
            for chunk in stream:
                if chunk.type == "text":
                    print(chunk.text, end="")

                if chunk.type == "content_block_start":
                    if chunk.content_block.type == "tool_use":
                        print(f'\n>>> Tool Call: "{chunk.content_block.name}"')

                if chunk.type == "input_json" and chunk.partial_json:
                    print(chunk.partial_json, end="")

                if chunk.type == "content_block_stop":
                    print("\n")

            response = stream.get_final_message()

        add_assistant_message(messages, response)

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

        if tool_choice:
            break

    return messages

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
    fine_grained=True
)
# Out:
# I'll create a fake computer science article and save it right away!
#
#
# >>> Tool Call: "save_article"
# {"abstract": "This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive gradient compression and dynamic topology reconfiguration to achieve near-linear scalability across heterogeneous computing clusters.", "meta": {"word_count": 7842, "review": "This paper introduces NeuroMesh, a distributed deep learning framework that addresses longstanding bottlenecks in large-scale model training. The authors propose an adaptive gradient compression algorithm that dynamically adjusts compression ratios based on real-time network bandwidth and node latency metrics. A key innovation is the dynamic topology reconfiguration module, which restructures the communication graph during training to minimize synchronization overhead. Experimental results are presented across three benchmark datasets, including ImageNet and a proprietary NLP corpus, demonstrating up to 94% parallel efficiency on 512-node clusters. The paper is well-structured and the theoretical complexity analysis is rigorous, though some assumptions about network homogeneity feel overly optimistic. Comparisons against existing frameworks such as Horovod and PyTorch DDP are thorough and fairly conducted. The ablation studies effectively isolate the contribution of each proposed component, lending credibility to the overall performance claims. Overall, NeuroMesh represents a meaningful step forward in scalable distributed training, and the open-source release of the codebase will likely drive adoption and follow-up research."}}
#
# The fake computer science article has been created and saved! Here's a summary of what was generated:
#
# ---
#
# ### 📄 NeuroMesh: Adaptive Gradient Compression for Scalable Distributed Deep Learning
#
# - **Abstract:** Introduces *NeuroMesh*, a distributed deep learning framework using adaptive gradient compression and dynamic topology reconfiguration for near-linear scalability on heterogeneous clusters.
# - **Word Count:** 7,842 words
# - **Review Highlights:**
#   - Proposes a dynamic gradient compression algorithm responsive to real-time network conditions.
#   - Achieves **94% parallel efficiency** on 512-node clusters across benchmarks like ImageNet.
#   - Benchmarked against Horovod and PyTorch DDP with rigorous ablation studies.
#   - Minor criticism around assumptions of network homogeneity.
#   - Praised for open-source release and strong theoretical foundations.
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "I'll create a fake computer science article and save it right away!"},
#    {'type': 'tool_use',
#     'id': 'toolu_bdrk_01YDgzfNAKaxii4an3apfogJ',
#     'name': 'save_article',
#     'input': {'abstract': 'This paper presents NeuroMesh, a novel distributed deep learning framework that leverages adaptive gradient compression and dynamic topology reconfiguration to achieve near-linear scalability across heterogeneous computing clusters.',
#      'meta': {'word_count': 7842,
#       'review': 'This paper introduces NeuroMesh, a distributed deep learning framework that addresses longstanding bottlenecks in large-scale model training. The authors propose an adaptive gradient compression algorithm that dynamically adjusts compression ratios based on real-time network bandwidth and node latency metrics. A key innovation is the dynamic topology reconfiguration module, which restructures the communication graph during training to minimize synchronization overhead. Experimental results are presented across three benchmark datasets, including ImageNet and a proprietary NLP corpus, demonstrating up to 94% parallel efficiency on 512-node clusters. The paper is well-structured and the theoretical complexity analysis is rigorous, though some assumptions about network homogeneity feel overly optimistic. Comparisons against existing frameworks such as Horovod and PyTorch DDP are thorough and fairly conducted. The ablation studies effectively isolate the contribution of each proposed component, lending credibility to the overall performance claims. Overall, NeuroMesh represents a meaningful step forward in scalable distributed training, and the open-source release of the codebase will likely drive adoption and follow-up research.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01YDgzfNAKaxii4an3apfogJ',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "The fake computer science article has been created and saved! Here's a summary of what was generated:\n\n---\n\n### 📄 NeuroMesh: Adaptive Gradient Compression for Scalable Distributed Deep Learning\n\n- **Abstract:** Introduces *NeuroMesh*, a distributed deep learning framework using adaptive gradient compression and dynamic topology reconfiguration for near-linear scalability on heterogeneous clusters.\n- **Word Count:** 7,842 words\n- **Review Highlights:**\n  - Proposes a dynamic gradient compression algorithm responsive to real-time network conditions.\n  - Achieves **94% parallel efficiency** on 512-node clusters across benchmarks like ImageNet.\n  - Benchmarked against Horovod and PyTorch DDP with rigorous ablation studies.\n  - Minor criticism around assumptions of network homogeneity.\n  - Praised for open-source release and strong theoretical foundations."}]}]
