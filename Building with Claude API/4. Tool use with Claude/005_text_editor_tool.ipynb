# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
    base_url=os.getenv("ANTHROPIC_BASE_URI")
)
model = "claude-sonnet-4-6"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic
import os

load_dotenv()

client = Anthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
    base_url=os.getenv("ANTHROPIC_BASE_URI")
)
model = "claude-sonnet-4-6"
print("client ready")
# Out:
# client ready

# %%
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])
print("helpers ready")
# Out:
# helpers ready

# %%
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            self._backup_file(abs_path)

            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))
print("TextEditorTool ready")
# Out:
# TextEditorTool ready

# %%
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks


def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }


def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

print("run_tool/run_tools/schema/loop ready")
# Out:
# run_tool/run_tools/schema/loop ready

# %%
messages = []

add_user_message(
    messages,
    """
    Open the '.\\4. Tool use with Claude\\main.py' file and write out a function to calculate pi to the 5th digit.
    
    Then create a '.\\4. Tool use with Claude\\test.py file to test your application
    """,
)

run_conversation(messages)
# Out:
# Let me start by viewing the existing file to understand what's already there.
#
#
# The directory is flat — let me view the existing `main.py` and then create both files.
# Now I have a clear picture. Let me create both files simultaneously!
#
#
# Let's do a final review of both files to make sure everything looks great:
# Both files are ready! Here's a summary of what was done:
#
# ---
#
# ### `main.py` — `calculate_pi()` function
# The function uses the **Leibniz formula for π**:
#
# > π/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...
#
# **How it works:**
# - Iterates **1,000,000 times** to accumulate enough precision for 5 decimal places
# - Alternates between **adding and subtracting** fractions with odd denominators
# - Returns π **rounded to 5 decimal places** → `3.14159`
# - Accepts an optional `digits` parameter (defaults to `5`) for flexibility
#
# ---
#
# ### `test.py` — Unit Tests
# Two test classes covering both functions:
#
# | Test | Description |
# |---|---|
# | `test_pi_default_5_digits` | Result matches `round(math.pi, 5)` |
# | `test_pi_returns_float` | Return type is `float` |
# | `test_pi_correct_value` | Result exactly equals `3.14159` |
# | `test_pi_fewer_digits` | Correctly rounds to 2 and 0 decimal places |
# | `test_pi_more_digits` | Still accurate when requesting more digits |
# | `test_pi_within_tolerance` | Within `assertAlmostEqual` tolerance of true π |
# | `test_greeting_output` | `greeting()` prints `"Hi There"` to stdout |
#
# Run the tests with:
# ```bash
# python -m unittest test.py -v
# ```
# [{'role': 'user',
#   'content': "\n    Open the '.\\4. Tool use with Claude\\main.py' file and write out a function to calculate pi to the 5th digit.\n\n    Then create a '.\\4. Tool use with Claude\\test.py file to test your application\n    "},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Let me start by viewing the existing file to understand what's already there.", type='text'),
#    ToolUseBlock(id='toolu_bdrk_017f59cdMStNSwkEkGoZuy6R', caller=None, input={'command': 'view', 'path': '.\\4. Tool use with Claude\\main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_017f59cdMStNSwkEkGoZuy6R',
#     'content': 'Error: File not found',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_bdrk_015P276QCyv9bxvb1W1RVFJL', caller=None, input={'command': 'view', 'path': './4. Tool use with Claude'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_015P276QCyv9bxvb1W1RVFJL',
#     'content': 'Error: File not found',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_bdrk_012wMcVzA8WuBq4y2Mwyivae', caller=None, input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_012wMcVzA8WuBq4y2Mwyivae',
#     'content': '".backups\\n001_tools.ipynb\\n002_multi_turn_tools.ipynb\\n003_multi_turn_tools.ipynb\\n004_tool_streaming.ipynb\\n005_text_editor_tool.ipynb\\nmain.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='The directory is flat — let me view the existing `main.py` and then create both files.', type='text'),
#    ToolUseBlock(id='toolu_bdrk_01AN1MWDd98rYAReh7KYcubT', caller=None, input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01AN1MWDd98rYAReh7KYcubT',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi There\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Now I have a clear picture. Let me create both files simultaneously!', type='text'),
#    ToolUseBlock(id='toolu_bdrk_01JgQi3SSxJHjmhpR6L7njCy', caller=None, input={'command': 'create', 'path': './main.py', 'file_text': 'def greeting():\n    print("Hi There")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate Pi to the specified number of decimal places.\n    Uses the Leibniz formula for Pi:\n      π/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\n    A high number of iterations is used to ensure accuracy up to 5 decimal places.\n\n    Args:\n        digits (int): The number of decimal places to return. Defaults to 5.\n\n    Returns:\n        float: Pi rounded to the specified number of decimal places.\n    """\n    numerator = 4.0\n    denominator = 1.0\n    operation = 1.0\n    pi = 0.0\n    iterations = 1_000_000  # More iterations = more precision\n\n    for _ in range(iterations):\n        pi += operation * (numerator / denominator)\n        denominator += 2.0\n        operation *= -1.0  # Alternate between adding and subtracting\n\n    return round(pi, digits)\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01JgQi3SSxJHjmhpR6L7njCy',
#     'content': 'Error: File already exists. Use str_replace to modify it.',
#     'is_error': True}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_bdrk_01AKCjvPGc3WukUEmk77iwBo', caller=None, input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def greeting():\n    print("Hi There")', 'new_str': 'def greeting():\n    print("Hi There")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate Pi to the specified number of decimal places.\n    Uses the Leibniz formula for Pi:\n      π/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\n    A high number of iterations is used to ensure accuracy up to 5 decimal places.\n\n    Args:\n        digits (int): The number of decimal places to return. Defaults to 5.\n\n    Returns:\n        float: Pi rounded to the specified number of decimal places.\n    """\n    numerator = 4.0\n    denominator = 1.0\n    operation = 1.0\n    pi = 0.0\n    iterations = 1_000_000  # More iterations = more precision\n\n    for _ in range(iterations):\n        pi += operation * (numerator / denominator)\n        denominator += 2.0\n        operation *= -1.0  # Alternate between adding and subtracting\n\n    return round(pi, digits)'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01AKCjvPGc3WukUEmk77iwBo',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_bdrk_016qv8Wepxdmtnx5m1pcG8pu', caller=None, input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nimport math\nfrom main import calculate_pi, greeting\nfrom io import StringIO\nimport sys\n\n\nclass TestCalculatePi(unittest.TestCase):\n\n    def test_pi_default_5_digits(self):\n        """Pi calculated to 5 decimal places should match math.pi rounded to 5 places."""\n        result = calculate_pi()\n        expected = round(math.pi, 5)  # 3.14159\n        self.assertEqual(result, expected, f"Expected {expected}, got {result}")\n\n    def test_pi_returns_float(self):\n        """calculate_pi() should return a float."""\n        result = calculate_pi()\n        self.assertIsInstance(result, float)\n\n    def test_pi_correct_value(self):\n        """Pi to 5 digits should equal 3.14159."""\n        result = calculate_pi()\n        self.assertEqual(result, 3.14159)\n\n    def test_pi_fewer_digits(self):\n        """calculate_pi() should correctly round to fewer decimal places."""\n        self.assertEqual(calculate_pi(2), round(math.pi, 2))  # 3.14\n        self.assertEqual(calculate_pi(0), round(math.pi, 0))  # 3.0\n\n    def test_pi_more_digits(self):\n        """calculate_pi() with more digits should still be close to math.pi."""\n        result = calculate_pi(6)\n        self.assertAlmostEqual(result, math.pi, places=5)\n\n    def test_pi_within_tolerance(self):\n        """Pi should be within a small tolerance of the true value."""\n        result = calculate_pi(5)\n        self.assertAlmostEqual(result, math.pi, places=5)\n\n\nclass TestGreeting(unittest.TestCase):\n\n    def test_greeting_output(self):\n        """greeting() should print \'Hi There\' to stdout."""\n        captured = StringIO()\n        sys.stdout = captured\n        greeting()\n        sys.stdout = sys.__stdout__\n        self.assertEqual(captured.getvalue().strip(), "Hi There")\n\n\nif __name__ == "__main__":\n    unittest.main()\n'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_016qv8Wepxdmtnx5m1pcG8pu',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Let's do a final review of both files to make sure everything looks great:", type='text'),
#    ToolUseBlock(id='toolu_bdrk_01LAgJ9KQXC2dCWiSNTNG4X8', caller=None, input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None),
#    ToolUseBlock(id='toolu_bdrk_01WFhxJFMb6HpfLmaUw8R4d9', caller=None, input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use', toolset_name=None)]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01LAgJ9KQXC2dCWiSNTNG4X8',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi There\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate Pi to the specified number of decimal places.\\n8:     Uses the Leibniz formula for Pi:\\n9:       \\u03c0/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\\n10:     A high number of iterations is used to ensure accuracy up to 5 decimal places.\\n11: \\n12:     Args:\\n13:         digits (int): The number of decimal places to return. Defaults to 5.\\n14: \\n15:     Returns:\\n16:         float: Pi rounded to the specified number of decimal places.\\n17:     \\"\\"\\"\\n18:     numerator = 4.0\\n19:     denominator = 1.0\\n20:     operation = 1.0\\n21:     pi = 0.0\\n22:     iterations = 1_000_000  # More iterations = more precision\\n23: \\n24:     for _ in range(iterations):\\n25:         pi += operation * (numerator / denominator)\\n26:         denominator += 2.0\\n27:         operation *= -1.0  # Alternate between adding and subtracting\\n28: \\n29:     return round(pi, digits)"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_bdrk_01WFhxJFMb6HpfLmaUw8R4d9',
#     'content': '"1: import unittest\\n2: import math\\n3: from main import calculate_pi, greeting\\n4: from io import StringIO\\n5: import sys\\n6: \\n7: \\n8: class TestCalculatePi(unittest.TestCase):\\n9: \\n10:     def test_pi_default_5_digits(self):\\n11:         \\"\\"\\"Pi calculated to 5 decimal places should match math.pi rounded to 5 places.\\"\\"\\"\\n12:         result = calculate_pi()\\n13:         expected = round(math.pi, 5)  # 3.14159\\n14:         self.assertEqual(result, expected, f\\"Expected {expected}, got {result}\\")\\n15: \\n16:     def test_pi_returns_float(self):\\n17:         \\"\\"\\"calculate_pi() should return a float.\\"\\"\\"\\n18:         result = calculate_pi()\\n19:         self.assertIsInstance(result, float)\\n20: \\n21:     def test_pi_correct_value(self):\\n22:         \\"\\"\\"Pi to 5 digits should equal 3.14159.\\"\\"\\"\\n23:         result = calculate_pi()\\n24:         self.assertEqual(result, 3.14159)\\n25: \\n26:     def test_pi_fewer_digits(self):\\n27:         \\"\\"\\"calculate_pi() should correctly round to fewer decimal places.\\"\\"\\"\\n28:         self.assertEqual(calculate_pi(2), round(math.pi, 2))  # 3.14\\n29:         self.assertEqual(calculate_pi(0), round(math.pi, 0))  # 3.0\\n30: \\n31:     def test_pi_more_digits(self):\\n32:         \\"\\"\\"calculate_pi() with more digits should still be close to math.pi.\\"\\"\\"\\n33:         result = calculate_pi(6)\\n34:         self.assertAlmostEqual(result, math.pi, places=5)\\n35: \\n36:     def test_pi_within_tolerance(self):\\n37:         \\"\\"\\"Pi should be within a small tolerance of the true value.\\"\\"\\"\\n38:         result = calculate_pi(5)\\n39:         self.assertAlmostEqual(result, math.pi, places=5)\\n40: \\n41: \\n42: class TestGreeting(unittest.TestCase):\\n43: \\n44:     def test_greeting_output(self):\\n45:         \\"\\"\\"greeting() should print \'Hi There\' to stdout.\\"\\"\\"\\n46:         captured = StringIO()\\n47:         sys.stdout = captured\\n48:         greeting()\\n49:         sys.stdout = sys.__stdout__\\n50:         self.assertEqual(captured.getvalue().strip(), \\"Hi There\\")\\n51: \\n52: \\n53: if __name__ == \\"__main__\\":\\n54:     unittest.main()\\n55: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Both files are ready! Here\'s a summary of what was done:\n\n---\n\n### `main.py` — `calculate_pi()` function\nThe function uses the **Leibniz formula for π**:\n\n> π/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\n\n**How it works:**\n- Iterates **1,000,000 times** to accumulate enough precision for 5 decimal places\n- Alternates between **adding and subtracting** fractions with odd denominators\n- Returns π **rounded to 5 decimal places** → `3.14159`\n- Accepts an optional `digits` parameter (defaults to `5`) for flexibility\n\n---\n\n### `test.py` — Unit Tests\nTwo test classes covering both functions:\n\n| Test | Description |\n|---|---|\n| `test_pi_default_5_digits` | Result matches `round(math.pi, 5)` |\n| `test_pi_returns_float` | Return type is `float` |\n| `test_pi_correct_value` | Result exactly equals `3.14159` |\n| `test_pi_fewer_digits` | Correctly rounds to 2 and 0 decimal places |\n| `test_pi_more_digits` | Still accurate when requesting more digits |\n| `test_pi_within_tolerance` | Within `assertAlmostEqual` tolerance of true π |\n| `test_greeting_output` | `greeting()` prints `"Hi There"` to stdout |\n\nRun the tests with:\n```bash\npython -m unittest test.py -v\n```', type='text')]}]
